# %% [markdown]
# ### Langchain Version V1

# %%
import os
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

def get_weather(city: str) -> str:
    """Get the weather in a given city"""
    return f"The weather in {city} is sunny"

model = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    api_key=os.getenv("GOOGLE_API_KEY"),
)

agent = create_agent(
    model=model,
    tools=[get_weather],
    system_prompt="You are a helpful assistant.",
)

response = agent.invoke({
    "messages": [{"role": "user", "content": "What is the weather like in Pune? And what is current timing right now in Pune"}]
})

print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': "The weather in Pune is currently **sunny**. \n\nRegarding the time, Pune operates on **Indian Standard Time (IST, UTC+5:30)**. Since I don't have access to a real-time clock, please check your local device or clock for the exact current minute!", 'extras': {'signature': '...'}}]
